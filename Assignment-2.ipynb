# %%
length=int(input("Enter Length of Area"))
width=int(input("Enter Width of Area"))
area=length*width
print("Area of a Rectangle is ",area)
# Out:
# Enter Length of Area 10
# Enter Width of Area 10
# Area of a Rectangle is  100

# %%
r=int(input("Enter Radius of a Circumference"))
print(f"Circumference is {2*3.142*r}")
# Out:
# Enter Radius of a Circumference 10
# Circumference is 62.839999999999996

# %%
# Principle = int(input("Enter Principle " ))
Rate = eval(input("Enter Rate " ))
Time = eval(input("Enter Time " ))
Simpleinterest = Principle*Rate*Time
print(f"Simple Interest is {Simpleinterest}")

# %%
Distance = eval(input("Please Enter distance"))
Time = eval(input("Please enter Time"))
Speed = Distance/Time
print(f"Speed is {Speed}")
# Out:
# Please Enter distance 1
# Please enter Time 2
# Speed is 0.5

# %%
Weight = eval(input("Enter weight "))
Height = eval(input("Enter height "))
BMI = Weight/(Height)**2
print(f"BMI is {BMI}")

# %%
m = eval(input("Enter mass "))
a = eval(input("Enter acceleration "))
F = m*a
print(f"Force on an object is {F}")

# %%
P = eval(input("Enter principal amount"))
r = float(input("Enter annual rate"))
n = eval(input("Enter number of times interest is compounded per year"))
t = eval(input("Enter time in years"))
A = P*(1+(r/n))**n-t
print(f"Compund Interest is {A}")

# %%
a = eval(input("Enter a"))
b = eval(input("Enter b"))
c = eval(input("Enter c"))
P = a+b+c
print(f"Perimeter is {P}")

# %%
r = eval(input("Enter radius of sphere "))
pi = 3.142
V = (4/3)*pi*r**3
print(f"Volume of sphere is {V}")

# %%
m = eval(input("Enter mass "))
v = eval(input("Enter velocity"))
KE= (1/2)*m*v**2
print(f"KE is {KE}")

# %%
a = eval(input("Enter a "))
b = eval(input("Enter b "))
c = eval(input("Enter c "))
D = (b**2)-4*a*c
e = (-b+math.sqrt(D))/(2*a)
f = (-b-math.sqrt(D))/(2*a)
print(f"The Quadratic is = {e},{f}")

# %%
d = eval(input("Enter temperature "))
e = ((9/5)*C)+32
print(f"Temperature is {e}")

# %%
a = eval(input("Enter "))
b = eval(input("Enter "))
r = eval(input("Enter radius  "))
G = 6.67e-11
c = (G*a*b)/r**2
print(f"Gavitaional Force is  {c}")

# %%
r = eval(input("Enter radius of cylinder"))
h = eval(input("Enter height of cylinder "))
pi = 3.142
V = pi*r**2*h
print(f"Volume of cylinder is {V}")

# %%
c = eval(input("Enter Force"))
b = eval(input("Enter Area  "))
d = c/b
print(f"Pressure exerted by force on surface is = {d}")

# %%
v = eval(input("Enter Voltage"))
i = eval(input("Enter Current "))
P = v/i
print(f"Electric power is {p}")

# %%
r = eval(input("Enter radius in "))
pi = 3.142
P = 2*pi*r
print(f"Perimeter of circle is {P}")

# %%
PV = eval(input("Enter present value "))
r = float(input("Enter annual interest rate "))
t = eval(input("Enter time in years"))
FV = PV*(1+r)**t
print(f"Future value of investment is {FV}")

# %%
F = eval(input("Enter force "))
d = eval(input("Enter distance"))
theta = eval(input("Enter theta in degrees "))
W = F*d*theta
print(f"Workdone {W}")

# %%
m = eval(input("Enter mass in kg"))
c = eval(input("Enter specific heat  "))
delta = eval(input("Enter change in temperature "))
Q = m*c*delta
print(f"Heat transfer is {Q}")
